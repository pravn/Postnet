# %%
import torch
from torchvision import transforms, utils

# %%
import torchvision
import torchvision.datasets as dset

# %%
image_dataset = torchvision.datasets.ImageFolder('/home/praveen/projects/perception/BDD100k/BDD100K/images/100k',transform=data_transforms)

# %%
import os

# %%
cd /home/praveen/projects/Speech/postnet_experiments/Postnet
# Out:
# /home/praveen/projects/Speech/postnet_experiments/Postnet

# %%
dataset = dset.ImageFolder('./imagedata',
                               transform=transforms.Compose([
                                   #transforms.Resize(opt.imageSize),
                                   #transforms.RandomCrop(256),
                                   transforms.ToTensor(),
                                   transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                               ]))

# %%
len(dataset)
# Out:
# 1

# %%
type(dataset)
# Out:
# torchvision.datasets.folder.ImageFolder

# %%
count = 0
import numpy as np
import matplotlib.pyplot as plt
for i, data in enumerate(dataset):
    d = data[0].numpy()
    plt.imshow(np.transpose(d,(1,2,0)))
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
d.shape
# Out:
# (3, 256, 256)

# %%
plt.imshow(np.transpose(d,(1,2,0)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
